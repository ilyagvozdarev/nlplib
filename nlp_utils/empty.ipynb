# %%
# удаление и очистку памяти лучше вызывать отдельно, так как одновременно может не сработать
# для удаления тензоров достаточно сделать только очистку памяти (вторую ячейку)

import gc
import torch
# model.cpu()
del model

# %%
def collect():
    torch.cuda.ipc_collect()
    gc.collect()
    torch.cuda.empty_cache()

# %%
torch.cuda.ipc_collect()
gc.collect()
torch.cuda.empty_cache()

# %%
import importlib
import nlp_utils.training.timing
importlib.reload(nlp_utils.training.timing)
from nlp_utils.training.timing import since_remaining_time

# %%
# если произошла утечка памяти в контейнере (бывает если остановить скрипт прерыванием) - убить все python процессы:
# !pkill -9 python

# 2 вариант:
# !pkill -9 python
# !kill -9 [pid]

# %%
# !pkill -9 python
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pickle
with open('data.pickle', 'wb') as f:
    pickle.dump(data, f)

# %%
with open('data.pickle', 'rb') as f:
    data_new = pickle.load(f)

# %%
# mem

# !du -h -a -d 1 /home/NLP
print()
# !du -h -a -d 1 /home/raid/igvozdarev
print()

# !du -h -a -d 0 /home/raid/NLP/nlp_datasets/ssa/data_text /home/raid/NLP/nlp_datasets/ssa/prompting 

# !du -h -a -d 0 /home/raid/hf_cache/models--Qwen--Qwen3-32B /home/raid/hf_cache/models--RefalMachine--RuadaptQwen2.5-14B-Instruct /home/raid/hf_cache/models--RefalMachine--RuadaptQwen3-32B-Instruct
# Out:
# 72M	/home/NLP/repo
# 36G	/home/NLP/ASP
# 1.6M	/home/NLP/modules
# 4.0K	/home/NLP/raid
# 8.0K	/home/NLP/.vscode
# 4.0K	/home/NLP/gpus.sh
# 137M	/home/NLP/diarizationlm
# 36G	/home/NLP
#
# 20G	/home/raid/igvozdarev/NER
# 9.4G	/home/raid/igvozdarev/sentiment_analysis
# 83M	/home/raid/igvozdarev/TEST_ipynb
# 82M	/home/raid/igvozdarev/Storages
# 136M	/home/raid/igvozdarev/diarizationlm
# 36G	/home/raid/igvozdarev/RASA
# 65G	/home/raid/igvozdarev
#
# 113M	/home/raid/NLP/nlp_datasets/ssa/data_text
# 177M	/home/raid/NLP/nlp_datasets/ssa/prompting
# 62G	/home/raid/hf_cache/models--Qwen--Qwen3-32B
# 28G	/home/raid/hf_cache/models--RefalMachine--RuadaptQwen2.5-14B-Instruct
# 61G	/home/raid/hf_cache/models--RefalMachine--RuadaptQwen3-32B-Instruct

# %%
# utts_1 = load_data_from_files(
#     get_files_from_dir(dir=dir_update), 
#     extractor = load_from_json
# )

# utts_2 = load_data_from_files(
#     get_files_from_dir(dir='data/samples/v_5/handmade/all_'), 
#     extractor = load_from_json
# )

# srav_utts(utts_1, utts_2, verbose_if_no_id=True)

# %%
# !rm -r /home/NLP/diarizationlm/checkpoints
# !rm -r ~/.cache/huggingface/hub/models--natong19--Mistral-Nemo-Instruct-2407-abliterated
# !rm -r ~/.cache/huggingface/hub/models--yandex--YandexGPT-5-Lite-8B-instruct

# %%
# !ls /root/.cache/huggingface/hub
# Out:
# models--RefalMachine--RuadaptQwen2.5-14B-Instruct  version.txt
# models--deepseek-ai--DeepSeek-R1-Distill-Qwen-14B

# %%
# !du -h -a -d 3 /home/NLP /home/.cache ~/.cache | sort -h
# Out:
# 0	/root/.cache/huggingface/datasets/_root_.cache_huggingface_datasets_HuggingFaceH4___ultrachat_200k_default_0.0.0_8049631c405ae6576f93f445c6b8166f76f5505a.lock
# 0	/root/.cache/huggingface/datasets/_root_.cache_huggingface_datasets_IlyaGusev___saiga_scored_default_0.0.0_69b69f456e74cc5b8291862baf86cbf66d32d5f9.lock
# 0	/root/.cache/huggingface/datasets/_root_.cache_huggingface_datasets_IlyaGusev___saiga_scored_default_0.0.0_8814a5a0a4eaadcab9b7d6bc78af4476e2c534e3.lock
# 0	/root/.cache/huggingface/datasets/_root_.cache_huggingface_datasets_RefalMachine___darumeru_multiq_0.0.0_63c951c330635cdbf810e28937b0d7a6e1e0e64a.lock
# 0	/root/.cache/huggingface/datasets/_root_.cache_huggingface_datasets_RefalMachine___darumeru_multiq_0.0.0_aa98587d7c0b7e8e437dba126bb452daa1de386b.lock
# 0	/root/.cache/huggingface/datasets/_root_.cache_huggingface_datasets_conll2003_conll2003_1.0.0_9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98.lock
# ...

# %%
# !pip cache purge
# Out:
# WARNING: No matching packages
# Files removed: 0 (0 bytes)

# %%
from huggingface_hub import login

login(token='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')
