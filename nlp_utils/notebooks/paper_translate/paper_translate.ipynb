# %%
import re

f = open('paper.txt', 'r')

text = f.read()
text = '\n\n'.join([s.replace('\n', ' ') for s in re.split(r'\n{2,}', text)])
text = re.sub(r'(\w)- (\w)', r'\1\2', text)

fw = open('paper_new.txt', 'w')
fw.write(text)
fw.close()

# %%
p,b,r = 0.9, 20, 450

# %%
1 - (1-p**b)**r
# Out:
# 1.0

# %%
(1-p**b)**r
# Out:
# 4.64238524355869e-26

# %%
# Нормализуем перед перемножением
import torch.nn.functional as F
embeddings = F.normalize(embeddings, p=2, dim=1)  # ← добавить
