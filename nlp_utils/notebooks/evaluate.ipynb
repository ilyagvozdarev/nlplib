# %%
# !pip install evaluate
# Out:
# ...
#    ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/84.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/84.0 kB ? eta -:--:--
#    -------------- ------------------------- 30.7/84.0 kB 435.7 kB/s eta 0:00:01
#    ----------------------------- ---------- 61.4/84.0 kB 465.5 kB/s eta 0:00:01
#    ---------------------------------------  81.9/84.0 kB 508.4 kB/s eta 0:00:01
#    ---------------------------------------- 84.0/84.0 kB 469.9 kB/s eta 0:00:00
# ...

# %%
import evaluate

seqeval = evaluate.load("seqeval", trust_remote_code=True)

# %%
seqeval.compute(predictions=[['1', '1', '0']], references=[['1', '1', '0']])
# Out:
# {'overall_precision': 0.0,
#  'overall_recall': 0.0,
#  'overall_f1': 0.0,
#  'overall_accuracy': 1.0}
