# %%
import json

# %%
for chunk in json.JSONEncoder().iterencode({"foo": ["bar", "baz"]}):
    print(chunk, "\n")
# Out:
# {
#
# "foo"
#
# :
#
# ["bar"
#
# , "baz"
#
# ]
#
# }

# %%
json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}, True, '123'])
# Out:
# '["foo", {"bar": ["baz", null, 1.0, 2]}, true, "123"]'

# %%
json.dumps({'bar': 1})
# Out:
# '{"bar": 1}'

# %%
def func():
    pass

# %%
json.dumps(['asd', 1])
# Out:
# '["asd", 1]'
